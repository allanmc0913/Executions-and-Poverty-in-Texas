# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

sns.set(style='dark', color_codes=True, font_scale=1.3)

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
df_inmates = pd.read_csv('exinmates.csv', encoding="latin-1")
df_inmates = df_inmates.set_index("Execution No.")
df_inmates
# Out:
#                TDCJ Number   First Name    Last Name Date Received  \
# Execution No.
# 545                 999275        Ruben     Cardenas       7/29/98
# 544                 999411       Robert       Pruett       4/30/02
# 543                 999494      Taichin       Preyor       3/30/05
# 542                    997        James        Bigby           NaN
# 541                 999145      Rolando         Ruiz           NaN
# 540                 999463        Terry      Edwards       12/4/03
# 539                 999533  Christopher      Wilkins       3/12/08
# 538                 999481       Barney       Fuller       7/21/04
# 537                 999297        Pablo      Vasquez       3/30/99
# 536                 999525         Adam         Ward           NaN
# 535                 999281          Coy     Wesbrook        9/2/98
# 534                 999018      Gustavo       Garcia           NaN
# 533                 999539        James      Freeman      11/10/08
# 532                 999414      Richard    Masterson       5/15/02
# 531                 999419      Raphael      Holiday       6/21/02
# 530                 999432        Licho    Escamilla       11/1/02
# 529                 999360         Juan       Garcia       6/21/00
# 528                 999555       Daniel        Lopez       3/16/10
# 527                 999430      Gregory      Russeau      10/15/02
# 526                    764       Lester        Bower           NaN
# 525                 999451      Derrick      Charles       5/27/03
# 524                 999434       Manuel        Garza       11/8/02
# 523                 999471         Kent      Sprouse        3/1/04
# 522                 999336       Manuel      Vasquez      11/30/99
# 521                 999403       Donald      Newbury       1/28/02
# 520                 999237       Robert         Ladd       8/29/97
# 519                 999149       Arnold       Prieto           NaN
# 518                 999400       Miguel      Paredes       11/9/01
# 517                 999511         Lisa      Coleman       6/22/06
# 516                 999085       Willie      Trottie           NaN
# ...                    ...          ...          ...           ...
# 30                     624         Leon         King           NaN
# 29                     738      Raymond  Landry, Sr.           NaN
# 28                     546       Donald     Franklin           NaN
# 27                     746       Robert    Streetman           NaN
# 26                     586       Joseph    Starvaggi           NaN
# 25                     610         John     Thompson           NaN
# 24                     739       Elliot      Johnson           NaN
# 23                     619      Anthony     Williams           NaN
# 22                     759       Eliseo       Moreno           NaN
# 21                     667        Ramon    Hernandez       9/30/80
# 20                     774      Richard      Andrade           NaN
# 19                     608      Michael        Evans           NaN
# 18                     678      Chester       Wicker           NaN
# 17                     643        Larry        Smith           NaN
# 16                     646        Randy       Woolls           NaN
# 15                     522      Kenneth        Brock           NaN
# 14                     606         Rudy     Esquivel           NaN
# 13                     686          Jay    Pinkerton           NaN
# 12                     714      Jeffery       Barney           NaN
# 11                     662      Charles         Bass           NaN
# 10                     555      Charles     Rumbaugh           NaN
# 9                      551        Henry       Porter           NaN
# 8                      628      Charles       Milton           NaN
# 7                      713        Jesse   De La Rosa           NaN
# 6                      712      Stephen        Morin           NaN
# 5                      518        Doyle     Skillern           NaN
# 4                      621       Thomas     Barefoot           NaN
# 3                      529       Ronald      O'Bryan           NaN
# 2                      670        James        Autry      10/10/80
# 1                      592      Charlie  Brooks, Jr.       4/25/78
#
#                Age Received Date of Offense  Age at Offense Execution Date  \
# Execution No.
# 545                    28.0         2/22/97            26.0        11/9/17
# 544                    22.0        12/17/99            20.0       10/12/17
# 543                    34.0         2/26/04            33.0        7/27/17
# 542                     NaN             NaN             NaN        3/14/17
# 541                     NaN             NaN             NaN         3/7/17
# 540                    30.0          7/8/02            28.0        1/26/17
# 539                    39.0        10/28/05            37.0        1/11/17
# 538                    45.0         5/14/03            44.0        10/5/16
# 537                    21.0         4/18/98            20.0         4/6/16
# 536                     NaN             NaN             NaN        3/22/16
# 535                    40.0        11/13/97            39.0         3/9/16
# 534                     NaN             NaN             NaN        2/16/16
# 533                    27.0         3/17/07            26.0        1/27/16
# 532                    30.0          2/9/01            28.0        1/20/16
# 531                    22.0          9/6/00            21.0       11/18/15
# 530                    20.0        11/25/01            20.0       10/14/15
# 529                    20.0         9/17/98            18.0        10/6/15
# 528                    22.0         3/11/09            21.0        8/12/15
# 527                    33.0         5/30/01            31.0        6/18/15
# 526                     NaN             NaN             NaN         6/3/15
# 525                    20.0          7/2/02            19.0        5/12/15
# 524                    22.0          2/2/01            20.0        4/15/15
# 523                    31.0         10/6/02            30.0         4/9/15
# 522                    31.0         3/19/98            29.0        3/12/15
# 521                    39.0        12/24/00            38.0         2/4/15
# 520                    40.0         9/25/96            39.0        1/29/15
# 519                     NaN             NaN             NaN        1/21/15
# 518                    19.0         9/17/00            18.0       10/28/14
# 517                    30.0         7/26/04            28.0        9/17/14
# 516                     NaN             NaN             NaN        9/10/14
# ...                     ...             ...             ...            ...
# 30                      NaN             NaN             NaN        3/22/89
# 29                      NaN             NaN             NaN       12/13/88
# 28                      NaN             NaN             NaN        11/3/88
# 27                      NaN             NaN             NaN         1/7/88
# 26                      NaN             NaN             NaN        9/10/87
# 25                      NaN             NaN             NaN         7/8/87
# 24                      NaN             NaN             NaN        6/24/87
# 23                      NaN             NaN             NaN        5/28/87
# 22                      NaN             NaN             NaN         3/4/87
# 21                     38.0         6/20/80            38.0        1/30/87
# 20                      NaN             NaN             NaN       12/18/86
# 19                      NaN             NaN             NaN        12/4/86
# 18                      NaN             NaN             NaN        8/26/86
# 17                      NaN             NaN             NaN        8/22/86
# 16                      NaN             NaN             NaN        8/20/86
# 15                      NaN             NaN             NaN        6/19/86
# 14                      NaN             NaN             NaN         6/9/86
# 13                      NaN             NaN             NaN        5/15/86
# 12                      NaN             NaN             NaN        4/16/86
# 11                      NaN             NaN             NaN        3/12/86
# 10                      NaN             NaN             NaN        9/11/85
# 9                       NaN             NaN             NaN         7/9/85
# 8                       NaN             NaN             NaN        6/25/85
# 7                       NaN             NaN             NaN        5/15/85
# 6                       NaN             NaN             NaN        3/13/85
# 5                       NaN             NaN             NaN        1/16/85
# 4                       NaN             NaN             NaN       10/30/84
# 3                       NaN             NaN             NaN        3/31/84
# 2                      26.0         4/20/80            25.0        3/14/84
# 1                      35.0        12/14/76            34.0        12/7/82
#
#                Execution Age  Gender      ...      Education Level Weight  \
# Execution No.                             ...
# 545                       47    Male      ...                 11.0  204.0
# 544                       38    Male      ...                  8.0  160.0
# 543                       46    Male      ...                 10.0  219.0
# 542                       61     NaN      ...                  NaN    NaN
# 541                       44     NaN      ...                  NaN    NaN
# 540                       43    Male      ...                 12.0  157.0
# 539                       48    Male      ...                 12.0  196.0
# 538                       58    Male      ...                  9.0  225.0
# 537                       38    Male      ...                  8.0  174.0
# 536                       33     NaN      ...                  NaN    NaN
# 535                       58    Male      ...                  8.0  296.0
# 534                       43     NaN      ...                  NaN    NaN
# 533                       35    Male      ...                 12.0  155.0
# 532                       43    Male      ...                  6.0  233.0
# 531                       36    Male      ...                  9.0  194.0
# 530                       33    Male      ...                  8.0  156.0
# 529                       35    Male      ...                  8.0  183.0
# 528                       27    Male      ...                 10.0  140.0
# 527                       46    Male      ...                 11.0  299.0
# 526                       67     NaN      ...                  NaN    NaN
# 525                       32    Male      ...                 11.0  179.0
# 524                       34    Male      ...                 10.0  157.0
# 523                       42    Male      ...                 12.0  222.0
# 522                       46    Male      ...                  8.0  195.0
# 521                       53    Male      ...                  6.0  215.0
# 520                       57    Male      ...                 10.0  232.0
# 519                       42     NaN      ...                  NaN    NaN
# 518                       32    Male      ...                  8.0  254.0
# 517                       38  Female      ...                 10.0  189.0
# 516                       45     NaN      ...                  NaN    NaN
# ...                      ...     ...      ...                  ...    ...
# 30                        44     NaN      ...                  NaN    NaN
# 29                        39     NaN      ...                  NaN    NaN
# 28                        37     NaN      ...                  NaN    NaN
# 27                        27     NaN      ...                  NaN    NaN
# 26                        34     NaN      ...                  NaN    NaN
# 25                        32     NaN      ...                  NaN    NaN
# 24                        38     NaN      ...                  NaN    NaN
# 23                        27     NaN      ...                  NaN    NaN
# 22                        27     NaN      ...                  NaN    NaN
# 21                        44    Male      ...                  9.0  130.0
# 20                        25     NaN      ...                  NaN    NaN
# 19                        30     NaN      ...                  NaN    NaN
# 18                        37     NaN      ...                  NaN    NaN
# 17                        30     NaN      ...                  NaN    NaN
# 16                        36     NaN      ...                  NaN    NaN
# 15                        37     NaN      ...                  NaN    NaN
# 14                        50     NaN      ...                  NaN    NaN
# 13                        24     NaN      ...                  NaN    NaN
# 12                        28     NaN      ...                  NaN    NaN
# 11                        30     NaN      ...                  NaN    NaN
# 10                        28     NaN      ...                  NaN    NaN
# 9                         43     NaN      ...                  NaN    NaN
# 8                         34     NaN      ...                  NaN    NaN
# 7                         24     NaN      ...                  NaN    NaN
# 6                         34     NaN      ...                  NaN    NaN
# 5                         49     NaN      ...                  NaN    NaN
# 4                         39     NaN      ...                  NaN    NaN
# 3                         39     NaN      ...                  NaN    NaN
# 2                         29    Male      ...                  6.0  137.0
# 1                         40    Male      ...                 12.0  150.0
#
#                                     Eye Color  Hair Color  Native State  \
# Execution No.
# 545                                     Brown       Black        Mexico
# 544                                     Brown      Blonde         Texas
# 543                                     Brown       Black         Texas
# 542                                       NaN         NaN           NaN
# 541                                       NaN         NaN           NaN
# 540                                     Brown       Black         Texas
# 539                                     Green       Brown         Texas
# 538                                     Brown       Brown          Ohio
# 537                                     Brown       Black         Texas
# 536                                       NaN         NaN           NaN
# 535                                     Brown       Brown         Texas
# 534                                       NaN         NaN           NaN
# 533                                     Brown       Brown         Texas
# 532                                     Brown       Brown         Texas
# 531                                     Brown       Black         Texas
# 530                                     Brown       Black         Texas
# 529                                     Brown       Black         Texas
# 528                                     Brown       Black         Texas
# 527                                     Brown       Black         Texas
# 526                                       NaN         NaN           NaN
# 525                                     Brown       Black         Texas
# 524                                     Brown       Black         Texas
# 523                                     Hazel       Brown      Missouri
# 522                                     Brown       Black         Idaho
# 521                                     Brown       Brown    New Mexico
# 520                                     Brown       Black         Texas
# 519                                       NaN         NaN           NaN
# 518                                     Brown       Black      Illinois
# 517                                     Brown       Black         Texas
# 516                                       NaN         NaN           NaN
# ...                                       ...         ...           ...
# 30                                        NaN         NaN           NaN
# 29                                        NaN         NaN           NaN
# 28                                        NaN         NaN           NaN
# 27                                        NaN         NaN           NaN
# 26                                        NaN         NaN           NaN
# 25                                        NaN         NaN           NaN
# 24                                        NaN         NaN           NaN
# 23                                        NaN         NaN           NaN
# 22                                        NaN         NaN           NaN
# 21                                      Brown       Black         Texas
# 20                                        NaN         NaN           NaN
# 19                                        NaN         NaN           NaN
# 18                                        NaN         NaN           NaN
# 17                                        NaN         NaN           NaN
# 16                                        NaN         NaN           NaN
# 15                                        NaN         NaN           NaN
# 14                                        NaN         NaN           NaN
# 13                                        NaN         NaN           NaN
# 12                                        NaN         NaN           NaN
# 11                                        NaN         NaN           NaN
# 10                                        NaN         NaN           NaN
# 9                                         NaN         NaN           NaN
# 8                                         NaN         NaN           NaN
# 7                                         NaN         NaN           NaN
# 6                                         NaN         NaN           NaN
# 5                                         NaN         NaN           NaN
# 4                                         NaN         NaN           NaN
# 3                                         NaN         NaN           NaN
# 2                                       Brown       Brown         Texas
# 1              mar (according to DPS records)       Black         Texas
#
#                                                   Last Statement Sentiment  \
# Execution No.
# 545            This is my statement:ÌâåÊ My final words.ÌâåÊ ...        -1
# 544            I just want to let everyone in here to know I ...        -1
# 543            First and foremost I'd like to say, "Justice h...         1
# 542            Yes, I do, Grace Kehler is that you? I have gi...        -1
# 541            Yes sir, I would first like to say to the Sanc...         1
# 540            Yes, I made peace with God. I hope y'all make ...         1
# 539                                                         None         0
# 538            I don't have anything to say, you can proceed ...        -1
# 537            I just want to tell my family thank you, my mo...         1
# 536            I would like to thank everyone that has showed...        -1
# 535            Yeah, first off, I want to say that I am sorry...        -1
# 534            To my family, to my mom, I love you. God bless...         1
# 533                                                        None.         0
# 532            Sending me to a better place.ÌâåÊ I am alright...         1
# 531            Yes, I would like to thank all of my supporter...         1
# 530            Shelby, God bless your heart.ÌâåÊ To my family...         0
# 529            (Spanish) To the Solano family, I want to tell...         1
# 528            I would like to thank you.ÌâåÊ I hope this exe...         1
# 527            Yes, I would like to thank my family and frien...         1
# 526            "Much has been written about this case, not al...         1
# 525                                        I'm ready to go home.        -1
# 524            "Thank you for being here. I am sorry for all ...        -1
# 523            I would like to apologize to the Moreno family...         1
# 522            Yes sir, I want to say I love you to all my fa...         1
# 521            That each new indignity defeats only the body....         1
# 520            Joanna I really love and care about her, I app...         1
# 519            There are no endings, only beginnings. Love ya...         1
# 518            To the victimÌ¢åÛåªs family, I want you to kno...         0
# 517            I just want to tell my family  I love them; my...         1
# 516            Nesha, I love you. I hope this brings you some...        -1
# ...                                                          ...       ...
# 30             I would like to tell Mr. Richard that I apprec...         1
# 29              This offender declined to make a last statement.         0
# 28              This offender declined to make a last statement.         0
# 27              This offender declined to make a last statement.         0
# 26              This offender declined to make a last statement.         0
# 25              This offender declined to make a last statement.         0
# 24              This offender declined to make a last statement.         0
# 23             Mother, I am sorry for all the pain IÌ¢åÛåªve ...         1
# 22              This offender declined to make a last statement.         0
# 21              This offender declined to make a last statement.         0
# 20              This offender declined to make a last statement.         0
# 19             I want to say IÌ¢åÛåªm sorry for the things IÌ...        -1
# 18              This offender declined to make a last statement.         0
# 17             Tell my mother I love her and continue on with...         0
# 16             Goodbye to my family; I love all of you, IÌ¢åÛ...         1
# 15                             I have no last words. I am ready.        -1
# 14             Goodbye to all my friends; be cool. Thank you ...         0
# 13             "Be strong for me," Pinkerton told his father,...         0
# 12              This offender declined to make a last statement.         0
# 11                 I deserve this. Tell everyone I said goodbye.        -1
# 10             D.J., Laurie, Dr. Wheat, about all I can say i...         1
# 9              I want to thank Father Walsh for his spiritual...         0
# 8              ThereÌ¢åÛåªs no God but Allah, and unto thy I ...         0
# 7               This offender declined to make a last statement.         0
# 6              Heavenly Father, I give thanks for this time, ...         1
# 5              I pray that my family will rejoice and will fo...         1
# 4              When asked if he had a last statement, he repl...         0
# 3              What is about to transpire in a few moments is...         1
# 2               This offender declined to make a last statement.         0
# 1              Statement to the Media: I, at this very moment...        -1
#
#                                                    More Info URL  \
# Execution No.
# 545            https://www.tdcj.state.tx.us/death_row/dr_info...
# 544            https://www.tdcj.state.tx.us/death_row/dr_info...
# 543            https://www.tdcj.state.tx.us/death_row/dr_info...
# 542            https://www.tdcj.state.tx.us/death_row/dr_info...
# 541            https://www.tdcj.state.tx.us/death_row/dr_info...
# 540            https://www.tdcj.state.tx.us/death_row/dr_info...
# 539            https://www.tdcj.state.tx.us/death_row/dr_info...
# 538            https://www.tdcj.state.tx.us/death_row/dr_info...
# 537            https://www.tdcj.state.tx.us/death_row/dr_info...
# 536            https://www.tdcj.state.tx.us/death_row/dr_info...
# 535            https://www.tdcj.state.tx.us/death_row/dr_info...
# 534            https://www.tdcj.state.tx.us/death_row/dr_info...
# 533            https://www.tdcj.state.tx.us/death_row/dr_info...
# 532            https://www.tdcj.state.tx.us/death_row/dr_info...
# 531            https://www.tdcj.state.tx.us/death_row/dr_info...
# 530            https://www.tdcj.state.tx.us/death_row/dr_info...
# 529            https://www.tdcj.state.tx.us/death_row/dr_info...
# 528            https://www.tdcj.state.tx.us/death_row/dr_info...
# 527            https://www.tdcj.state.tx.us/death_row/dr_info...
# 526            https://www.tdcj.state.tx.us/death_row/dr_info...
# 525            https://www.tdcj.state.tx.us/death_row/dr_info...
# 524            https://www.tdcj.state.tx.us/death_row/dr_info...
# 523            https://www.tdcj.state.tx.us/death_row/dr_info...
# 522            https://www.tdcj.state.tx.us/death_row/dr_info...
# 521            https://www.tdcj.state.tx.us/death_row/dr_info...
# 520            https://www.tdcj.state.tx.us/death_row/dr_info...
# 519            https://www.tdcj.state.tx.us/death_row/dr_info...
# 518            https://www.tdcj.state.tx.us/death_row/dr_info...
# 517            https://www.tdcj.state.tx.us/death_row/dr_info...
# 516            https://www.tdcj.state.tx.us/death_row/dr_info...
# ...                                                          ...
# 30             https://www.tdcj.state.tx.us/death_row/dr_info...
# 29             https://www.tdcj.state.tx.us/death_row/dr_info...
# 28             https://www.tdcj.state.tx.us/death_row/dr_info...
# 27             https://www.tdcj.state.tx.us/death_row/dr_info...
# 26             https://www.tdcj.state.tx.us/death_row/dr_info...
# 25             https://www.tdcj.state.tx.us/death_row/dr_info...
# 24             https://www.tdcj.state.tx.us/death_row/dr_info...
# 23             https://www.tdcj.state.tx.us/death_row/dr_info...
# 22             https://www.tdcj.state.tx.us/death_row/dr_info...
# 21             https://www.tdcj.state.tx.us/death_row/dr_info...
# 20             https://www.tdcj.state.tx.us/death_row/dr_info...
# 19             https://www.tdcj.state.tx.us/death_row/dr_info...
# 18             https://www.tdcj.state.tx.us/death_row/dr_info...
# 17             https://www.tdcj.state.tx.us/death_row/dr_info...
# 16             https://www.tdcj.state.tx.us/death_row/dr_info...
# 15             https://www.tdcj.state.tx.us/death_row/dr_info...
# 14             https://www.tdcj.state.tx.us/death_row/dr_info...
# 13             https://www.tdcj.state.tx.us/death_row/dr_info...
# 12             https://www.tdcj.state.tx.us/death_row/dr_info...
# 11             https://www.tdcj.state.tx.us/death_row/dr_info...
# 10             https://www.tdcj.state.tx.us/death_row/dr_info...
# 9              https://www.tdcj.state.tx.us/death_row/dr_info...
# 8              https://www.tdcj.state.tx.us/death_row/dr_info...
# 7              https://www.tdcj.state.tx.us/death_row/dr_info...
# 6              https://www.tdcj.state.tx.us/death_row/dr_info...
# 5              https://www.tdcj.state.tx.us/death_row/dr_info...
# 4              https://www.tdcj.state.tx.us/death_row/dr_info...
# 3              https://www.tdcj.state.tx.us/death_row/dr_info...
# 2              https://www.tdcj.state.tx.us/death_row/dr_info...
# 1              https://www.tdcj.state.tx.us/death_row/dr_info...
#
#                                               Last Statement URL  Poverty Rate
# Execution No.
# 545            https://www.tdcj.state.tx.us/death_row/dr_info...          45.4
# 544            https://www.tdcj.state.tx.us/death_row/dr_info...          26.6
# 543            https://www.tdcj.state.tx.us/death_row/dr_info...          21.6
# 542            https://www.tdcj.state.tx.us/death_row/dr_info...          12.3
# 541            https://www.tdcj.state.tx.us/death_row/dr_info...          19.4
# 540            https://www.tdcj.state.tx.us/death_row/dr_info...          13.8
# 539            https://www.tdcj.state.tx.us/death_row/dr_info...          10.0
# 538            https://www.tdcj.state.tx.us/death_row/dr_info...          27.2
# 537            https://www.tdcj.state.tx.us/death_row/dr_info...          45.4
# 536            https://www.tdcj.state.tx.us/death_row/dr_info...          16.6
# 535            https://www.tdcj.state.tx.us/death_row/dr_info...          15.6
# 534            https://www.tdcj.state.tx.us/death_row/dr_info...           5.3
# 533            https://www.tdcj.state.tx.us/death_row/dr_info...          18.9
# 532            https://www.tdcj.state.tx.us/death_row/dr_info...          15.6
# 531            https://www.tdcj.state.tx.us/death_row/dr_info...          28.3
# 530            https://www.tdcj.state.tx.us/death_row/dr_info...          13.8
# 529            https://www.tdcj.state.tx.us/death_row/dr_info...          15.6
# 528            https://www.tdcj.state.tx.us/death_row/dr_info...          21.1
# 527            https://www.tdcj.state.tx.us/death_row/dr_info...          15.5
# 526            https://www.tdcj.state.tx.us/death_row/dr_info...          14.6
# 525            https://www.tdcj.state.tx.us/death_row/dr_info...          15.6
# 524            https://www.tdcj.state.tx.us/death_row/dr_info...          21.6
# 523            https://www.tdcj.state.tx.us/death_row/dr_info...          11.8
# 522            https://www.tdcj.state.tx.us/death_row/dr_info...          21.6
# 521            https://www.tdcj.state.tx.us/death_row/dr_info...          13.8
# 520            https://www.tdcj.state.tx.us/death_row/dr_info...          15.5
# 519            https://www.tdcj.state.tx.us/death_row/dr_info...          19.4
# 518            https://www.tdcj.state.tx.us/death_row/dr_info...          21.6
# 517            https://www.tdcj.state.tx.us/death_row/dr_info...          10.0
# 516            https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# ...                                                          ...           ...
# 30             https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 29             https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 28             https://www.tdcj.state.tx.us/death_row/dr_info...          22.8
# 27             https://www.tdcj.state.tx.us/death_row/dr_info...          13.7
# 26             https://www.tdcj.state.tx.us/death_row/dr_info...          11.5
# 25             https://www.tdcj.state.tx.us/death_row/dr_info...          19.4
# 24             https://www.tdcj.state.tx.us/death_row/dr_info...          20.0
# 23             https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 22             https://www.tdcj.state.tx.us/death_row/dr_info...           9.4
# 21             https://www.tdcj.state.tx.us/death_row/dr_info...          31.5
# 20             https://www.tdcj.state.tx.us/death_row/dr_info...          22.8
# 19             https://www.tdcj.state.tx.us/death_row/dr_info...          14.5
# 18             https://www.tdcj.state.tx.us/death_row/dr_info...          15.0
# 17             https://www.tdcj.state.tx.us/death_row/dr_info...          14.5
# 16             https://www.tdcj.state.tx.us/death_row/dr_info...          17.1
# 15             https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 14             https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 13             https://www.tdcj.state.tx.us/death_row/dr_info...          22.8
# 12             https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 11             https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 10             https://www.tdcj.state.tx.us/death_row/dr_info...          21.6
# 9              https://www.tdcj.state.tx.us/death_row/dr_info...          12.3
# 8              https://www.tdcj.state.tx.us/death_row/dr_info...          12.3
# 7              https://www.tdcj.state.tx.us/death_row/dr_info...          19.4
# 6              https://www.tdcj.state.tx.us/death_row/dr_info...          20.0
# 5              https://www.tdcj.state.tx.us/death_row/dr_info...          19.7
# 4              https://www.tdcj.state.tx.us/death_row/dr_info...          14.6
# 3              https://www.tdcj.state.tx.us/death_row/dr_info...          19.1
# 2              https://www.tdcj.state.tx.us/death_row/dr_info...          18.4
# 1              https://www.tdcj.state.tx.us/death_row/dr_info...          10.0
#
# [545 rows x 23 columns]

# %%
pov_rates = pd.read_csv('pov_rates.csv')
county_codes = pd.read_csv('county_codes.csv')

# %%
county_codes.head()
# Out:
#      County  FIPS #
# 0  Anderson       1
# 1   Andrews       3
# 2  Angelina       5
# 3   Aransas       7
# 4    Archer       9

# %%
pov_rates.head()
# Out:
#    FIPS #  Year  Rate
# 0       1  1989  20.5
# 1       1  1993  20.8
# 2       1  1995  20.1
# 3       1  1996   NaN
# 4       1  1997  20.4

# %%
pov_by_county = pd.merge(pov_rates, county_codes, on='FIPS #')
pov_by_county = pov_by_county.drop("FIPS #", axis=1).set_index("County")

# No data for 1996
pov_by_county = pov_by_county[pov_by_county.Year != 1996]

pov_by_county.head()
# Out:
#           Year  Rate
# County
# Anderson  1989  20.5
# Anderson  1993  20.8
# Anderson  1995  20.1
# Anderson  1997  20.4
# Anderson  1998  18.6

# %%
df_inmates['Age Received'].mean()
# Out:
# 28.564935064935064

# %%
df_inmates['Age at Offense'].mean()
# Out:
# 26.954545454545453

# %% [markdown]
# Most inmates on average enter death row approximately 2.5 years after their offense (quick turn around time).

# %%
df_inmates['Execution Age'].mean()
# Out:
# 39.3394495412844

# %% [markdown]
# Most inmates on average stay on death row for approximately 11 years before being executed.

# %%
df_inmates['Gender'].value_counts()
# Out:
# Male      150
# Female      3
# male        1
# Name: Gender, dtype: int64

# %% [markdown]
# Clearly, males outnumber females.

# %%
df_inmates['Race'].value_counts()
# Out:
# White       242
# Black       198
# Hispanic    103
# Other         2
# Name: Race, dtype: int64

# %% [markdown]
# A majority of inmates being White, with a close 2nd of Black.

# %%
df_inmates['Education Level'].max()
# Out:
# 12.0

# %%
df_inmates['Education Level'].min()
# Out:
# 3.0

# %%
df_inmates['Education Level'].mean()
# Out:
# 9.876623376623376

# %% [markdown]
# The lowest being 3rd grade and the highest finishing high school, inmates average an education level of 9th grade.

# %%
df_inmates['Sentiment'].value_counts()
# Out:
#  1    200
#  0    192
# -1    153
# Name: Sentiment, dtype: int64

# %% [markdown]
# A very close distribution between positive, negative, and neutral sentiments.  However, inmates are more positive at the time of their death.

# %%
df_inmates['Poverty Rate'].mean()
# Out:
# 17.570458715596356

# %% [markdown]
# The average poverty rate for each executed prisoner during their year of birth (or closest available year) is 17.57%

# %%
pov_by_county.groupby("Year").describe()
# Out:
#        Rate
#       count       mean       std  min     25%    50%     75%   max
# Year
# 1989  253.0  19.985771  8.634788  5.6  14.200  18.70  24.500  55.2
# 1993  254.0  20.132283  7.230473  4.3  15.925  19.40  23.100  49.9
# 1995  254.0  20.188583  7.788183  3.5  15.425  19.20  23.875  52.0
# 1997  254.0  19.279134  7.001682  4.7  14.700  18.40  23.000  46.7
# 1998  254.0  18.381102  6.583339  4.0  14.325  17.40  21.450  43.8
# 1999  254.0  17.548819  6.171128  4.4  13.925  16.70  20.050  44.9
# 2000  254.0  17.763780  6.139687  4.3  13.925  17.00  20.500  42.2
# 2001  254.0  17.674803  5.942591  4.7  13.625  16.90  20.600  40.4
# 2002  254.0  17.300000  5.667828  4.8  13.650  16.50  20.100  39.0
# 2003  254.0  16.821654  4.915978  5.4  13.800  16.40  19.175  36.4
# 2004  254.0  16.483858  4.975594  5.5  13.250  16.10  19.000  34.8
# 2005  254.0  18.510630  6.422915  5.0  14.500  18.10  21.175  45.7
# 2006  254.0  18.311417  6.285669  4.9  14.400  17.50  21.200  44.4
# 2007  254.0  17.403543  6.025016  5.0  13.625  16.50  20.100  40.7
# 2008  254.0  17.040945  5.724275  6.2  13.400  15.95  20.500  36.8
# 2009  254.0  17.983465  6.016273  5.5  14.125  17.20  20.700  41.6
# 2010  254.0  18.540157  6.020857  6.4  14.500  18.20  21.300  39.9
# 2011  254.0  18.704331  6.017374  6.0  14.625  17.90  21.775  39.3
# 2012  254.0  18.324803  5.915182  6.7  14.300  17.80  21.275  43.6
# 2013  254.0  18.149606  5.651617  6.6  14.225  17.90  21.600  43.1
# 2014  254.0  17.455512  5.480265  6.8  13.825  17.20  20.375  38.8
# 2015  254.0  16.818504  5.327074  6.0  13.200  16.50  19.975  35.4

# %% [markdown]
# Average poverty rates for all Texas counties for every available year.

# %%
avg_pov_rates = pov_by_county.groupby("County").describe()['Rate']['mean']

# %%
counties = df_inmates[['County', 'Poverty Rate']]

counties = counties.set_index("County")
counties['Inmates'] = df_inmates['County'].value_counts()
counties = counties.reset_index()

counties.head()
# Out:
#     County  Poverty Rate  Inmates
# 0  Hidalgo          45.4        6
# 1      Bee          26.6        2
# 2    Bexar          21.6       44
# 3  Tarrant          12.3       40
# 4    Bexar          19.4       44

# %%
sns.regplot(x="Poverty Rate", y="Inmates", data=counties)

# %%
np.corrcoef(x=counties["Poverty Rate"], y=counties["Inmates"])
# Out:
# array([[ 1.        ,  0.00732972],
#        [ 0.00732972,  1.        ]])

# %%
counties_3 = counties[counties.Inmates > 2]

# %%
np.corrcoef(x=counties_3["Poverty Rate"], y=counties_3["Inmates"])
# Out:
# array([[ 1.        ,  0.04892873],
#        [ 0.04892873,  1.        ]])

# %%
counties_10 = counties[counties.Inmates > 9]
np.corrcoef(x=counties_10["Poverty Rate"], y=counties_10["Inmates"])
# Out:
# array([[ 1.        ,  0.15838181],
#        [ 0.15838181,  1.        ]])

# %%
sns.regplot(x="Poverty Rate", y="Inmates", data=counties_10)

# %%
x = counties_10['Poverty Rate']
y = counties_10['Inmates']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

# %%
print (slope, intercept, r_value, p_value, std_err)
# Out:
# 2.1365622722 29.6298051643 0.158381810314 0.00265375859605 0.70594143739

# %%
counties = counties.set_index("County")
counties.head()
# Out:
#          Poverty Rate  Inmates
# County
# Hidalgo          45.4        6
# Bee              26.6        2
# Bexar            21.6       44
# Tarrant          12.3       40
# Bexar            19.4       44

# %%
avg_inmate_pov_rate = counties.groupby("County").describe()['Poverty Rate']['mean']

# %%
import bokeh.sampledata
from bokeh.io import show
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LogColorMapper
)
from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure

from bokeh.sampledata.us_counties import data as tx_counties

palette.reverse()

tx_counties = {
    code: county for code, county in tx_counties.items() if county["state"] == "tx"
}

county_xs = [county["lons"] for county in tx_counties.values()]
county_ys = [county["lats"] for county in tx_counties.values()]

county_names = [county['name'] for county in tx_counties.values()]
county_rates = [avg_inmate_pov_rate[name] if name in counties else avg_pov_rates[name] for name in county_names]

# %%
color_mapper = LogColorMapper(palette=palette)

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    name=county_names,
    rate=county_rates,
))

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    title="Texas Executed Inmates", tools=TOOLS,
    x_axis_location=None, y_axis_location=None
)
p.grid.grid_line_color = None

p.patches('x', 'y', source=source,
          fill_color={'field': 'rate', 'transform': color_mapper},
          fill_alpha=0.7, line_color="white", line_width=0.5)

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    ("Name", "@name"),
    ("Poverty rate)", "@rate%")
]

show(p)
