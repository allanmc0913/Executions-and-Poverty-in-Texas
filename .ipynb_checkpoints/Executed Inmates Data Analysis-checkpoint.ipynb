# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

sns.set(style='dark', color_codes=True, font_scale=1.3)

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
df_inmates = pd.read_csv('exinmates.csv', encoding="latin-1")
df_inmates = df_inmates.set_index("Execution No.")
df_inmates.head()
# Out:
#                TDCJ Number First Name Last Name Date Received  Age Received  \
# Execution No.
# 545                 999275      Ruben  Cardenas       7/29/98          28.0
# 544                 999411     Robert    Pruett       4/30/02          22.0
# 543                 999494    Taichin    Preyor       3/30/05          34.0
# 542                    997      James     Bigby           NaN           NaN
# 541                 999145    Rolando      Ruiz           NaN           NaN
#
#               Date of Offense  Age at Offense Execution Date  Execution Age  \
# Execution No.
# 545                   2/22/97            26.0        11/9/17             47
# 544                  12/17/99            20.0       10/12/17             38
# 543                   2/26/04            33.0        7/27/17             46
# 542                       NaN             NaN        3/14/17             61
# 541                       NaN             NaN         3/7/17             44
#
#               Gender      ...      Education Level Weight Eye Color  \
# Execution No.             ...
# 545             Male      ...                 11.0  204.0     Brown
# 544             Male      ...                  8.0  160.0     Brown
# 543             Male      ...                 10.0  219.0     Brown
# 542              NaN      ...                  NaN    NaN       NaN
# 541              NaN      ...                  NaN    NaN       NaN
#
#                Hair Color  Native State  \
# Execution No.
# 545                 Black        Mexico
# 544                Blonde         Texas
# 543                 Black         Texas
# 542                   NaN           NaN
# 541                   NaN           NaN
#
#                                                   Last Statement Sentiment  \
# Execution No.
# 545            This is my statement:ÌâåÊ My final words.ÌâåÊ ...        -1
# 544            I just want to let everyone in here to know I ...        -1
# 543            First and foremost I'd like to say, "Justice h...         1
# 542            Yes, I do, Grace Kehler is that you? I have gi...        -1
# 541            Yes sir, I would first like to say to the Sanc...         1
#
#                                                    More Info URL  \
# Execution No.
# 545            https://www.tdcj.state.tx.us/death_row/dr_info...
# 544            https://www.tdcj.state.tx.us/death_row/dr_info...
# 543            https://www.tdcj.state.tx.us/death_row/dr_info...
# 542            https://www.tdcj.state.tx.us/death_row/dr_info...
# 541            https://www.tdcj.state.tx.us/death_row/dr_info...
#
#                                               Last Statement URL  Poverty Rate
# Execution No.
# 545            https://www.tdcj.state.tx.us/death_row/dr_info...          45.4
# 544            https://www.tdcj.state.tx.us/death_row/dr_info...          26.6
# 543            https://www.tdcj.state.tx.us/death_row/dr_info...          21.6
# 542            https://www.tdcj.state.tx.us/death_row/dr_info...          12.3
# 541            https://www.tdcj.state.tx.us/death_row/dr_info...          19.4
#
# [5 rows x 23 columns]

# %%
df_inmates['Age Received'].mean()
# Out:
# 28.564935064935064

# %%
df_inmates['Age at Offense'].mean()
# Out:
# 26.954545454545453

# %% [markdown]
# Most inmates on average enter death row approximately 2.5 years after their offense (quick turn around time).

# %%
df_inmates['Execution Age'].mean()
# Out:
# 39.3394495412844

# %% [markdown]
# Most inmates on average stay on death row for approximately 11 years before being executed.

# %%
df_inmates['Gender'].value_counts()
# Out:
# Male      150
# Female      3
# male        1
# Name: Gender, dtype: int64

# %% [markdown]
# Clearly, males outnumber females.

# %%
df_inmates['Race'].value_counts()
# Out:
# White       242
# Black       198
# Hispanic    103
# Other         2
# Name: Race, dtype: int64

# %% [markdown]
# A majority of inmates being White, with a close 2nd of Black.

# %%
df_inmates['Education Level'].max()
# Out:
# 12.0

# %%
df_inmates['Education Level'].min()
# Out:
# 3.0

# %%
df_inmates['Education Level'].mean()
# Out:
# 9.876623376623376

# %% [markdown]
# The lowest being 3rd grade and the highest finishing high school, inmates average an education level of 9th grade.

# %%
df_inmates['Sentiment'].value_counts()
# Out:
#  1    200
#  0    192
# -1    153
# Name: Sentiment, dtype: int64

# %% [markdown]
# A very close distribution between positive, negative, and neutral sentiments.  However, inmates are more positive at the time of their death.

# %%
df_inmates['Poverty Rate'].mean()
# Out:
# 17.570458715596356

# %% [markdown]
# The average poverty county rate in Texas is 17.57%

# %%
# df_inmates['Census Year'] = [ if name in counties else 0 for inmate in df_inmates]

# for inmate in df_inmates:
#     print (df_inmates.ix[inmate])
#     if df_inmates[inmate]['Date Received'] != "N/A":
#         year = df_inmates[inmate]['Date Received'][-4:]
#     elif df_inmates[inmate]['Date of Offense'] != "N/A":
#         year = df_inmates[inmate]['Date of Offense'][-4:]
#     else:
#         year = 1995

#     if '/' in str(year):
#         year = 1989

#     year = int(year)

#     if year not in range(1995, 2016):
#         years = [1989, 1993]
#         year_diffs = {x: abs(year-x) for x in years}
#         year = min(year_diffs, key=lambda x: year_diffs[x])

#     df_inmates[inmate]['Census Year'] = year

print (pd.notna(df_inmates['Date Received']))

# df_inmates['Census Year'] = [89 if n == "nan" else int(str(n)[-2:]) for n in df_inmates['Date Received']]
# df_inmates['Census Year']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-8c2e49bbb869> in <module>()
#      22 #     df_inmates[inmate]['Census Year'] = year
#      23
# ---> 24 print (pd.notna(df_inmates['Date Received']))
#      25
#      26 # df_inmates['Census Year'] = [89 if n == "nan" else int(str(n)[-2:]) for n in df_inmates['Date Received']]
#
# AttributeError: module 'pandas' has no attribute 'notna'

# %%
counties = df_inmates[['County', 'Poverty Rate']]

counties = counties.set_index("County")
counties['Inmates'] = df_inmates['County'].value_counts()
counties.reset_index()
# counties = counties.drop_duplicates()

# counties.index.value_counts()
# Out:
#          County  Poverty Rate  Inmates
# 0       Hidalgo          45.4        6
# 1           Bee          26.6        2
# 2         Bexar          21.6       44
# 3       Tarrant          12.3       40
# 4         Bexar          19.4       44
# 5        Dallas          13.8       56
# 6       Tarrant          10.0       40
# 7       Houston          27.2        1
# 8       Hidalgo          45.4        6
# 9          Hunt          16.6        4
# 10       Harris          15.6      126
# 11       Collin           5.3        7
# 12      Wharton          18.9        1
# 13       Harris          15.6      126
# 14      Madison          28.3        1
# 15       Dallas          13.8       56
# 16       Harris          15.6      126
# 17       Nueces          21.1       16
# 18        Smith          15.5       12
# 19      Grayson          14.6        3
# 20       Harris          15.6      126
# 21        Bexar          21.6       44
# 22        Ellis          11.8        2
# 23        Bexar          21.6       44
# 24       Dallas          13.8       56
# 25        Smith          15.5       12
# 26        Bexar          19.4       44
# 27        Bexar          21.6       44
# 28      Tarrant          10.0       40
# 29       Harris          19.1      126
# ..          ...           ...      ...
# 515      Harris          19.1      126
# 516      Harris          19.1      126
# 517      Nueces          22.8       16
# 518      Hardin          13.7        1
# 519  Montgomery          11.5       15
# 520       Bexar          19.4       44
# 521   Jefferson          20.0       15
# 522      Harris          19.1      126
# 523   Fort Bend           9.4        5
# 524     El Paso          31.5        3
# 525      Nueces          22.8       16
# 526      Dallas          14.5       56
# 527   Galveston          15.0        6
# 528      Dallas          14.5       56
# 529   Tom Green          17.1        3
# 530      Harris          19.1      126
# 531      Harris          19.1      126
# 532      Nueces          22.8       16
# 533      Harris          19.1      126
# 534      Harris          19.1      126
# 535      Potter          21.6       10
# 536     Tarrant          12.3       40
# 537     Tarrant          12.3       40
# 538       Bexar          19.4       44
# 539   Jefferson          20.0       15
# 540     Lubbock          19.7       12
# 541        Bell          14.6        3
# 542      Harris          19.1      126
# 543   Jefferson          18.4       15
# 544     Tarrant          10.0       40
#
# [545 rows x 3 columns]

# %%
counties.groupby('County', counties['Poverty Rate']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-aad489d7be1f> in <module>()
# ----> 1 counties.groupby('County', counties['Poverty Rate']).mean()
#
# C:\Users\Jess\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4266         if level is None and by is None:
#    4267             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 4268         axis = self._get_axis_number(axis)
#    4269         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4270                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# C:\Users\Jess\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     339
#     340     def _get_axis_number(self, axis):
# --> 341         axis = self._AXIS_ALIASES.get(axis, axis)
#     342         if is_integer(axis):
#     343             if axis in self._AXIS_NAMES:
#
# C:\Users\Jess\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#     875     def __hash__(self):
#     876         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# --> 877                         ' hashed'.format(self.__class__.__name__))
#     878
#     879     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
sns.regplot(x="Poverty Rate", y="Inmates", data=counties)

# %%
np.corrcoef(x=counties["Poverty Rate"], y=counties["Inmates"])
# Out:
# array([[ 1.        , -0.07593707],
#        [-0.07593707,  1.        ]])

# %%
counties_3 = counties[counties.Inmates > 2]

# %%
np.corrcoef(x=counties_3["Poverty Rate"], y=counties_3["Inmates"])
# Out:
# array([[ 1.        , -0.02157115],
#        [-0.02157115,  1.        ]])

# %%
counties_10 = counties[counties.Inmates > 9]
np.corrcoef(x=counties_10["Poverty Rate"], y=counties_10["Inmates"])
# Out:
# array([[ 1.        , -0.15177072],
#        [-0.15177072,  1.        ]])

# %%
sns.regplot(x="Poverty Rate", y="Inmates", data=counties_10)

# %%
x = counties_10['Poverty Rate']
y = counties_10['Inmates']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

# %%
print (slope, intercept, r_value, p_value, std_err)
# Out:
# -1.32826654846 55.5546537099 -0.151770722622 0.500160599246 1.93429131673

# %%
counties.head()
# Out:
#          Poverty Rate  Inmates
# County
# Hidalgo          45.4        6
# Bee              26.6        2
# Bexar            21.6       44
# Tarrant          12.3       40
# Bexar            19.4       44

# %%
import bokeh.sampledata
from bokeh.io import show
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LogColorMapper
)
from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure

from bokeh.sampledata.us_counties import data as tx_counties
# from bokeh.sampledata.unemployment import data as unemployment

palette.reverse()

tx_counties = {
    code: county for code, county in tx_counties.items() if county["state"] == "tx"
}

county_xs = [county["lons"] for county in tx_counties.values()]
county_ys = [county["lats"] for county in tx_counties.values()]

county_names = [county['name'] for county in tx_counties.values()]

for n in county_names:
    try:
        print(counties.ix[n]['Poverty Rate'])
        print("__")
    except:
        print("not found")
        print("---")

county_rates = [counties.ix[name]['Poverty Rate'] if name in counties else 0 for name in county_names]
# Out:
# County
# Anderson    20.5
# Anderson    20.1
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# 22.2
# __
# not found
# ---
# not found
# ---
# 25.2
# __
# not found
# ---
# 22.8
# __
# not found
# ---
# 14.7
# __
# not found
# ---
# 26.6
# __
# 14.2
# __
# County
# Bexar    21.6
# Bexar    19.4
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Bowie    16.6
# Bowie    16.7
# Name: Poverty Rate, dtype: float64
# __
# County
# Brazoria     9.9
# Brazoria    11.6
# Name: Poverty Rate, dtype: float64
# __
# County
# Brazos    19.3
# Brazos    19.0
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 19.4
# __
# not found
# ---
# not found
# ---
# 21.6
# __
# not found
# ---
# not found
# ---
# 39.8
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Cherokee    21.4
# Cherokee    22.0
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# 11.2
# __
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Collin    5.3
# Collin    5.6
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# 10.5
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 13.1
# __
# not found
# ---
# not found
# ---
# 19.3
# __
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Dallas    13.8
# Dallas    14.5
# Name: Poverty Rate, dtype: float64
# __
# 29.7
# __
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Denton    5.8
# Denton    6.8
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 11.8
# __
# 31.5
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Fort Bend    8.1
# Fort Bend    9.4
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 15.0
# __
# not found
# ---
# 11.6
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 14.6
# __
# County
# Gregg    14.1
# Gregg    16.0
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# 23.6
# __
# not found
# ---
# 18.5
# __
# not found
# ---
# not found
# ---
# 13.7
# __
# County
# Harris    15.6
# Harris    19.1
# Name: Poverty Rate, dtype: float64
# __
# 19.5
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 17.7
# __
# County
# Hidalgo    45.4
# Hidalgo    42.2
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 15.0
# __
# 27.2
# __
# not found
# ---
# not found
# ---
# County
# Hunt    16.6
# Hunt    16.5
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Jefferson    18.4
# Jefferson    20.0
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# 12.5
# __
# 23.7
# __
# not found
# ---
# 13.3
# __
# 10.4
# __
# not found
# ---
# not found
# ---
# County
# Kerr    14.7
# Kerr    15.0
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 26.4
# __
# not found
# ---
# not found
# ---
# 20.2
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 17.8
# __
# 18.8
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 12.2
# __
# not found
# ---
# County
# Lubbock    19.5
# Lubbock    19.7
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# County
# McLennan    19.2
# McLennan    19.8
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# 28.3
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 18.9
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 21.5
# __
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Montgomery    10.1
# Montgomery    11.5
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# 19.2
# __
# not found
# ---
# 21.4
# __
# County
# Navarro    20.2
# Navarro    20.0
# Name: Poverty Rate, dtype: float64
# __
# 22.1
# __
# not found
# ---
# County
# Nueces    21.1
# Nueces    22.8
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 10.4
# __
# not found
# ---
# County
# Pecos    28.0
# Pecos    23.7
# Name: Poverty Rate, dtype: float64
# __
# 20.7
# __
# County
# Potter    20.4
# Potter    21.6
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# 7.9
# __
# not found
# ---
# not found
# ---
# 24.2
# __
# not found
# ---
# 20.1
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 17.6
# __
# not found
# ---
# 20.8
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 18.2
# __
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Smith    15.5
# Smith    15.9
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Tarrant    12.3
# Tarrant    10.0
# Name: Poverty Rate, dtype: float64
# __
# 17.1
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# County
# Tom Green    16.0
# Tom Green    17.1
# Name: Poverty Rate, dtype: float64
# __
# County
# Travis    12.9
# Travis    13.4
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 34.8
# __
# not found
# ---
# County
# Victoria    16.0
# Victoria    17.4
# Name: Poverty Rate, dtype: float64
# __
# 20.4
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---
# 18.9
# __
# not found
# ---
# not found
# ---
# 19.2
# __
# not found
# ---
# County
# Williamson    8.8
# Williamson    7.4
# Name: Poverty Rate, dtype: float64
# __
# not found
# ---
# not found
# ---
# not found
# ---
# 18.0
# __
# not found
# ---
# not found
# ---
# not found
# ---
# not found
# ---

# %%
color_mapper = LogColorMapper(palette=palette)

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    name=county_names,
    rate=county_rates,
))

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    title="Texas Executed Inmates", tools=TOOLS,
    x_axis_location=None, y_axis_location=None
)
p.grid.grid_line_color = None

p.patches('x', 'y', source=source,
          fill_color={'field': 'rate', 'transform': color_mapper},
          fill_alpha=0.7, line_color="white", line_width=0.5)

hover = p.select_one(HoverTool)
hover.point_policy = "follow_mouse"
hover.tooltips = [
    ("Name", "@name"),
    ("Poverty rate)", "@rate%"),
    ("(Long, Lat)", "($x, $y)"),
]

show(p)
